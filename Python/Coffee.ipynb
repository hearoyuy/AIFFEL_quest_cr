# %% [markdown]
# <a href="https://colab.research.google.com/github/hearoyuy/AIFFEL_quest_cr/blob/master/Python/Coffee.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing_extensions import Self
# 주문 번호 코드로 출력
print('⟝' + '-' * 30 + '⟞')
print('|' + ' ' * 31 + '|')
print('|' + ' ' * 31 + '|')
print('|' + ' ' * 31 + '|')
print('|' + ' ' * 31 + '|')
print('상품명 : HOT 아메리카노')
print('총 주문 금액 : 1500원')
print('|' + ' ' * 31 + '|')
print('|' + ' ' * 31 + '|')
print('|' + ' ' * 31 + '|')
print('|' + ' ' * 31 + '|')
print('⟝' + '-' * 30 + '⟞')

class Kiosk:
    def __init__(self):
        self.menu = ['americano', 'latte', 'mocha', 'yuza_tea', 'green_tea', 'choco_latte']
        self.price = [2000, 3000, 3000, 2500, 2500, 3000]

    def menu_print(self):
        for i in range(len(self.menu)):
            print(i+1, self.menu[i], ' : ', self.price[i], '원')

    def menu_select(self):
        self.order_menu = []                                                    #추가주문 리스트
        self.order_price = []
        n = 0
        while n < 1 or len(self.menu) < n:
            n = int(input("음료의 번호를 입력하세요 : "))                       # 음료 번호 입력

            if 1 <= n & n <= len(self.menu):
                self.order_price.append(self.price[n-1])                        # 가격 리스트에 추가합니다.
                self.price_sum = self.price[n-1]

            else:                                                               # 메뉴판에 없는 번호일 때
                print("없는 메뉴입니다. 다시 주문해 주세요.")

        t = 0
        while t != 1 and t != 2:                                                # 1이나 2를 입력할 때까지 물어보기
            t= int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))
            if t == 1:
                self.temp = "HOT"
            elif t == 2:
                self.temp = "ICE"
            else:
                print("1과 2 중 하나를 입력하세요.\n")

        print('주문 음료', self.temp, self.menu[n-1], ' : ', self.price[n-1], '원')

        #추가주문
        while n != 0:
            print()
            n = int(input("추가 주문은 음료 번호를, 지불은 0을 누르세요 : "))  # 추가 주문 또는 지불
            if n > 0 and n < len(self.menu) + 1:
                t = 0
                while t != 1 and t != 2:
                    t= int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))
                    if t == 1:
                        self.temp = "HOT"
                    elif t == 2:
                        self.temp = "ICE"
                    else:
                        print("1과 2 중 하나를 입력하세요.\n")
                self.order_price.append(self.price[n-1])
                self.order_menu.append(self.temp + ' ' + self.menu[n-1])
                self.price_sum +=  self.price[n-1]

                print('추가 주문 음료', self.temp, self.menu[n-1], ' : ', self.price[n-1], '원\n', '합계 : ', self.price_sum, '원')
            else :
                if n == 0:
                    print("주문이 완료되었습니다")
                    print(self.order_menu, self.order_price)
                else :
                    print("없는 메뉴입니다. 다시 주문해 주세요")

#Kiosk().menu
a = Kiosk()
a.menu_print()
a.menu_select()
# Out:
# ⟝------------------------------⟞
# |                               |
# |                               |
# |                               |
# |                               |
# 상품명 : HOT 아메리카노
# 총 주문 금액 : 1500원
# |                               |
# |                               |
# |                               |
# |                               |
# ⟝------------------------------⟞
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원
# 음료의 번호를 입력하세요 : 1
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 1
# 주문 음료 HOT americano  :  2000 원
#
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 2
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 2
# 추가 주문 음료 ICE latte  :  3000 원
#  합계 :  5000 원
#
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 3
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 3
# 1과 2 중 하나를 입력하세요.
#
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 2
# 추가 주문 음료 ICE mocha  :  3000 원
#  합계 :  8000 원
#
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 4
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 1
# 추가 주문 음료 HOT yuza_tea  :  2500 원
#  합계 :  10500 원
#
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 5
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 1
# 추가 주문 음료 HOT green_tea  :  2500 원
#  합계 :  13000 원
#
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 0
# 주문이 완료되었습니다
# ['ICE latte', 'ICE mocha', 'HOT yuza_tea', 'HOT green_tea'] [2000, 3000, 3000, 2500, 2500]
